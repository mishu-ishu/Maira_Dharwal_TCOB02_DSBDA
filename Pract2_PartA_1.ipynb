# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    70.000000           94.0           62.0             79.0            2018
# 1    61.000000           79.0           66.0             75.0            2018
# 2    80.000000           95.0           76.0             97.0            2020
# 3    80.000000           92.0           80.0             90.0            2020
# 4    63.000000           91.0           76.0             75.0            2021
# 5    95.000000           84.0           76.0             98.0            2018
# 6    71.928571           78.0           53.0             94.0            2021
# 7    61.000000           93.0            NaN             91.0            2019
# 8    68.000000           92.0           70.0             75.0            2019
# 9    63.000000           92.0           77.0             88.0            2019
# 10   80.000000           78.0           79.0            100.0            2021
# ...

# %%
ndf.dropna(how="all")
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    70.000000           94.0           62.0             79.0            2018
# 1    61.000000           79.0           66.0             75.0            2018
# 2    80.000000           95.0           76.0             97.0            2020
# 3    80.000000           92.0           80.0             90.0            2020
# 4    63.000000           91.0           76.0             75.0            2021
# 5    95.000000           84.0           76.0             98.0            2018
# 6    71.928571           78.0           53.0             94.0            2021
# 7    61.000000           93.0            NaN             91.0            2019
# 8    68.000000           92.0           70.0             75.0            2019
# 9    63.000000           92.0           77.0             88.0            2019
# 10   80.000000           78.0           79.0            100.0            2021
# ...

# %%
col=["Math_Score","Reading_Score","Writing_Score","Placement_Score"]
df.boxplot(col)
# Out:
# <Axes: >

# %%
import numpy as np
print(np.where(df["Math_Score"]<20))
# Out:
# (array([], dtype=int64),)

# %%
import numpy as np
sorted_mscore= sorted(df["Math_Score"])
sorted_mscore
# Out:
# [60.0,
#  60.0,
#  61.0,
#  61.0,
#  62.0,
#  63.0,
#  63.0,
#  63.0,
#  63.0,
#  65.0,
#  67.0,
#  68.0,
#  68.0,
#  70.0,
#  71.92857142857143,
#  71.92857142857143,
#  72.0,
#  74.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  78.0,
#  78.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  95.0,
#  99.0]

# %%
q1=np.percentile(sorted_mscore,25)
q3=np.percentile(sorted_mscore,75)
print(q1,q3)
# Out:
# 63.0 77.75

# %%
iqr= q3-q1

# %%
lwr_bound= q1-(1.5*iqr)
upr_bound = q3+(1.5*iqr)
print(lwr_bound,upr_bound)
# Out:
# 40.875 99.875

# %%
mout=[]
for i in sorted_mscore:
    if (i<lwr_bound or i>upr_bound):
      mout.append(i)
print(mout)
# Out:
# []

# %%
import numpy as np
sorted_rscore= sorted(df["Writing_Score"])
sorted_rscore
# Out:
# [53.0,
#  61.0,
#  62.0,
#  63.0,
#  64.0,
#  66.0,
#  66.0,
#  68.0,
#  69.0,
#  69.0,
#  70.0,
#  70.0,
#  72.0,
#  73.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  79.0,
#  80.0,
#  nan,
#  80.0,
#  nan,
#  80.0,
#  80.0]

# %%
q1=np.percentile(sorted_rscore,25)
q3=np.percentile(sorted_rscore,75)
print(q1,q3)
# Out:
# nan nan

# %%
import numpy as np
sorted_pscore= sorted(df["Placement_Score"])
sorted_pscore
# Out:
# [33.0,
#  75.0,
#  75.0,
#  75.0,
#  76.0,
#  79.0,
#  79.0,
#  82.0,
#  84.0,
#  85.0,
#  86.0,
#  87.0,
#  88.0,
#  89.0,
#  90.0,
#  91.0,
#  93.0,
#  94.0,
#  95.0,
#  97.0,
#  97.0,
#  97.0,
#  98.0,
#  98.0,
#  100.0,
#  100.0,
#  100.0,
#  nan,
#  101.0,
#  nan]

# %%
q1=np.percentile(sorted_pscore,25)
q3=np.percentile(sorted_pscore,75)
print(q1,q3)
# Out:
# nan nan

# %%
iqr= q3-q1

# %%
lwr_bound= q1-(1.5*iqr)
upr_bound = q3+(1.5*iqr)
print(lwr_bound,upr_bound)
# Out:
# nan nan

# %%
pout=[]
for i in sorted_pscore:
    if (i<lwr_bound or i>upr_bound):
      pout.append(i)
print(pout)
# Out:
# []

# %%
col = ['Reading_Score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
df['Math_Score'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['log_math'] = np.log10(df['Math_Score'])

# %%
df['log_math'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
